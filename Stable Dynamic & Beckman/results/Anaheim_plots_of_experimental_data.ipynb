# %%
## Data Initializing

# %%
import pandas as pd
import numpy as np
import data_handler as dh
import time
import matplotlib.pyplot as plt
from matplotlib import rc
import pickle

# %%
net_name = 'Anaheim_net.tntp'
trips_name = 'Anaheim_trips.tntp'

handler = dh.DataHandler()
graph_data = handler.GetGraphData(net_name, columns_order = np.array([0, 1, 2, 4]))
graph_correspondences, total_od_flow = handler.GetGraphCorrespondences(trips_name)

graph_data['graph_table'].head()
# Out:
#    Init node  Term node  Capacity  Free Flow Time
# 0          1        117    9000.0        1.090459
# 1          2         87    9000.0        1.090459
# 2          3         74    9000.0        1.090459
# 3          4        233    9000.0        1.090459
# 4          5        165    9000.0        1.090459

# %%
import model as md
model = md.Model(graph_data, graph_correspondences, 
                    total_od_flow, mu = 0.25, rho = 0.15)

graph_data['graph_table'].head()
# Out:
#    Init node  Term node  Capacity  Free Flow Time
# 0          1        117    9000.0        1.090459
# 1          2         87    9000.0        1.090459
# 2          3         74    9000.0        1.090459
# 3          4        233    9000.0        1.090459
# 4          5        165    9000.0        1.090459

# %% [markdown]
# ### For Stable Dynamic the cell below:

# %%
handler = dh.DataHandler()
graph_data = handler.GetGraphData(net_name, columns_order = np.array([0, 1, 2, 4]))
graph_data['graph_table']['Capacity'] = 2.5 * graph_data['graph_table']['Capacity']

model = md.Model(graph_data, graph_correspondences, 
                 total_od_flow, mu = 0, rho = 0.15)

graph_data['graph_table'].head()
# Out:
#    Init node  Term node  Capacity  Free Flow Time
# 0          1        117   22500.0        1.090459
# 1          2         87   22500.0        1.090459
# 2          3         74   22500.0        1.090459
# 3          4        233   22500.0        1.090459
# 4          5        165   22500.0        1.090459

# %% [markdown]
# ## Experiment relative error vs gamma

# %% [markdown]
# ### flow_star calculation for 2.5x capacity:

# %%
flows = []
times = []
iter_nums = []
primal_vals = []
dual_vals = []
dual_gaps = []

# %%
max_iter = 10000
for i, eps_abs in enumerate(np.logspace(1,3,5)):
    print('eps_abs =', eps_abs)
    solver_kwargs = {'eps_abs': eps_abs,
                     'max_iter': max_iter}
    tic = time.time()
    result = model.find_equilibrium(solver_name = 'ustf', solver_kwargs = solver_kwargs, verbose = False)
    toc = time.time()
    print('Elapsed time: {:.0f} sec'.format(toc - tic))
    
    print('Time ratio =', np.max(result['times'] / graph_data['graph_table']['Free Flow Time']))
    print('Flow excess =', np.max(result['flows'] / graph_data['graph_table']['Capacity']) - 1, end = '\n\n')
    
    result['eps_abs'] = eps_abs
    with open('anaheim_result_' + 'ustf' + '_#' + str(i) + '_max_iter_' + str(max_iter) + 
              '_2.5xCapacity.pickle', 'wb') as f:
        pickle.dump(result, f)
# Out:
# eps_abs = 10.0
# Elapsed time: 3303 sec
# Time ratio = 1.8929040131837573
# Flow excess = 0.0065381140687974515
#
# eps_abs = 31.622776601683793
# Elapsed time: 3283 sec
# Time ratio = 1.7974242927747626
# Flow excess = 0.0026937149523986736
#
# eps_abs = 100.0
# Elapsed time: 3285 sec
# Time ratio = 1.8499575639395323
# Flow excess = 0.0011616504563118912
#
# eps_abs = 316.22776601683796
# Elapsed time: 3292 sec
# Time ratio = 1.8508979190116792
# Flow excess = 0.0002183223720781946
#
# eps_abs = 1000.0
# Elapsed time: 3290 sec
# Time ratio = 1.8509012958031554
# Flow excess = 6.285231726588236e-05

# %%
with open('anaheim_result_ustf_eps_abs_1_max_iter_10000_3xCapacity.pickle', 'wb') as f:
    pickle.dump(result, f)

# %%
max_iter = 10000
for i, eps_abs in enumerate(np.logspace(1,3,5)):
    print('eps_abs =', eps_abs)
    solver_kwargs = {'eps_abs': eps_abs,
                     'max_iter': max_iter}
    tic = time.time()
    result = model.find_equilibrium(solver_name = 'ugd', solver_kwargs = solver_kwargs, verbose = False)
    toc = time.time()
    print('Elapsed time: {:.0f} sec'.format(toc - tic))
    
    print('Time ratio =', np.max(result['times'] / graph_data['graph_table']['Free Flow Time']))
    print('Flow excess =', np.max(result['flows'] / graph_data['graph_table']['Capacity']) - 1, end = '\n\n')
    
    result['eps_abs'] = eps_abs
    with open('anaheim_result_' + 'ugd' + '_#' + str(i) + '_max_iter_' + str(max_iter) + 
              '_2.5xCapacity.pickle', 'wb') as f:
        pickle.dump(result, f)
# Out:
# eps_abs = 10.0
# Elapsed time: 2809 sec
# Time ratio = 1.6824643373488442
# Flow excess = 0.019437826330495733
#
# eps_abs = 31.622776601683793
# Elapsed time: 2803 sec
# Time ratio = 1.850633096695186
# Flow excess = 0.009022138773227217
#
# eps_abs = 100.0
# Elapsed time: 2835 sec
# Time ratio = 1.8507696151732687
# Flow excess = 0.002693016123122227
#
# eps_abs = 316.22776601683796
# Elapsed time: 2904 sec
# Time ratio = 1.8490051269530985
# Flow excess = 0.001136132806513146
#
# eps_abs = 1000.0
# Elapsed time: 2821 sec
# Time ratio = 1.846173095703354
# Flow excess = 0.0003165824612991752

# %%
model.mu = 0
max_iter = 10000
for i, eps_abs in enumerate(np.logspace(1,3,5)):
    print('eps_abs =', eps_abs)
    solver_kwargs = {'eps_abs': eps_abs,
                     'max_iter': max_iter}
    tic = time.time()
    result = model.find_equilibrium(solver_name = 'sd', solver_kwargs = solver_kwargs, verbose = False)
    toc = time.time()
    print('Elapsed time: {:.0f} sec'.format(toc - tic))
    
    print('Time ratio =', np.max(result['times'] / graph_data['graph_table']['Free Flow Time']))
    print('Flow excess =', np.max(result['flows'] / graph_data['graph_table']['Capacity']) - 1, end = '\n\n')
    
    result['eps_abs'] = eps_abs
    with open('anaheim_result_' + 'sd' + '_#' + str(i) + '_max_iter_' + str(max_iter) + 
              '_2.5xCapacity.pickle', 'wb') as f:
        pickle.dump(result, f)
# Out:
# eps_abs = 10.0
# Elapsed time: 2860 sec
# Time ratio = 1.6817912686360952
# Flow excess = 0.022141660871784596
#
# eps_abs = 31.622776601683793
# Elapsed time: 2914 sec
# Time ratio = 1.8506276564255122
# Flow excess = 0.008236101571247323
#
# eps_abs = 100.0
# Elapsed time: 2993 sec
# Time ratio = 1.8508507197659547
# Flow excess = 0.0032011040126380674
#
# eps_abs = 316.22776601683796
# Elapsed time: 2881 sec
# Time ratio = 1.849675447809613
# Flow excess = 0.0009314130825985867
#
# eps_abs = 1000.0
# Elapsed time: 2893 sec
# Time ratio = 1.842598989878519
# Flow excess = 0.0003777599694165801

# %% [markdown]
# ###  flow star calculated and saved above

# %%
model.mu = 0.25
solver_kwargs = {'eps': 1e-2,
                 'eps_abs': 10,
                 'max_iter': 500}

tic = time.time()
result = model.find_equilibrium(solver_name = 'sd', solver_kwargs = solver_kwargs, verbose = True)
toc = time.time()
print('Elapsed time: {:.0f} sec'.format(toc - tic))
flows.append(result['flows'])
times.append(result['times'])
iter_nums.append(result['iter_num'])
primal_vals.append(result['primal_func_history'])
dual_vals.append(result['dual_func_history'])

# %%
print(np.max(times[-1] / graph_data['graph_table']['Free Flow Time']))
print(np.max(flows[-1] / graph_data['graph_table']['Capacity']) - 1)
# Out:
# 2.8045636761264485
# 0.023055659918054694

# %%
with open('anaheim_result_ustf_eps_abs_10_max_iter_10000_2xCapacity.pickle', 'wb') as f:
    pickle.dump(result, f)

# %% [markdown]
# ### Resullts

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
results = {}

max_iter = 10000
for i, eps_abs in enumerate(np.logspace(1,3,5)):
    with open('anaheim_result_' + 'ustf' + '_#' + str(i) + '_max_iter_' + str(max_iter) + 
              '_2.5xCapacity.pickle', 'rb') as f:
        result = pickle.load(f)
        results[('ustf', eps_abs)] = result
for i, eps_abs in enumerate(np.logspace(1,3,5)):
    with open('anaheim_result_' + 'ugd' + '_#' + str(i) + '_max_iter_' + str(max_iter) + 
              '_2.5xCapacity.pickle', 'rb') as f:
        result = pickle.load(f)
        results[('ugd', eps_abs)] = result
for i, eps_abs in enumerate(np.logspace(1,3,5)):
    with open('anaheim_result_' + 'sd' + '_#' + str(i) + '_max_iter_' + str(max_iter) + 
              '_2.5xCapacity.pickle', 'rb') as f:
        result = pickle.load(f)
        results[('sd', eps_abs)] = result

# %%
dual_min = np.inf
for _, result in results.items():
    dual_min = min(dual_min, np.min(result['dual_func_history']))
print(dual_min )
# Out:
# -1170707.7461515302

# %%
plt.figure(figsize=(15,6))
iter_step = 100
method = 'ustf'
plt.suptitle('Universal Similar Triangles', fontsize=20)

plt.subplot(1, 2, 1)
for i, eps_abs in enumerate(np.logspace(1,3,5)):
    result = results[(method, eps_abs)]
    y = result['dual_func_history'][::iter_step] - dual_min
    x = iter_step * np.arange(len(y))
    plt.plot(x, y, label=str(eps_abs))
plt.legend(title="eps_abs")
plt.ylabel('|dual function - dual_min|')
plt.xlabel('iterations')

plt.subplot(1, 2, 2)
for i, eps_abs in enumerate(np.logspace(1,3,5)):
    result = results[(method, eps_abs)]
    y = result['dual_func_history'][::iter_step] - dual_min
    x = iter_step * np.arange(len(y))
    plt.plot(x, y, label=str(eps_abs))
plt.legend(title="eps_abs")
plt.yscale('log')
plt.ylabel('|dual function - dual_min|')
plt.xlabel('iterations')

#plt.savefig('ustm_stable_dynamic.png')
plt.show()

# %%
plt.figure(figsize=(15,6))
iter_step = 100
method = 'ugd'
plt.suptitle('Universal Gradient Method', fontsize=20)

plt.subplot(1, 2, 1)
for i, eps_abs in enumerate(np.logspace(1,3,5)):
    result = results[(method, eps_abs)]
    y = result['dual_func_history'][::iter_step] - dual_min
    x = iter_step * np.arange(len(y))
    plt.plot(x, y, label=str(eps_abs))
plt.legend(title="eps_abs")
plt.ylabel('|dual function - dual_min|')
plt.xlabel('iterations')

plt.subplot(1, 2, 2)
for i, eps_abs in enumerate(np.logspace(1,3,5)):
    result = results[(method, eps_abs)]
    y = result['dual_func_history'][::iter_step] - dual_min
    x = iter_step * np.arange(len(y))
    plt.plot(x, y, label=str(eps_abs))
plt.legend(title="eps_abs")
plt.yscale('log')
plt.ylabel('|dual function - dual_min|')
plt.xlabel('iterations')

#plt.savefig('ugd_stable_dynamic.png')
plt.show()

# %%
plt.figure(figsize=(15,6))
iter_step = 100
method = 'sd'
plt.suptitle('Subgradient Method', fontsize=20)

plt.subplot(1, 2, 1)
for i, eps_abs in enumerate(np.logspace(1,3,5)):
    result = results[(method, eps_abs)]
    y = result['dual_func_history'][::iter_step] - dual_min
    x = iter_step * np.arange(len(y))
    plt.plot(x, y, label=str(eps_abs))
plt.legend(title="eps_abs")
plt.ylabel('|dual function - dual_min|')
plt.xlabel('iterations')

plt.subplot(1, 2, 2)
for i, eps_abs in enumerate(np.logspace(1,3,5)):
    result = results[(method, eps_abs)]
    y = result['dual_func_history'][::iter_step] - dual_min
    x = iter_step * np.arange(len(y))
    plt.plot(x, y, label=str(eps_abs))
plt.legend(title="eps_abs")
plt.yscale('log')
plt.ylabel('|dual function - dual_min|')
plt.xlabel('iterations')

#plt.savefig('subgradient_stable_dynamic.png')
plt.show()

# %%
# eps_1 
10.**1.5
# Out:
# 31.622776601683793

# %%
plt.figure(figsize=(15,6))
eps_abs = np.logspace(1,3,5)[1] # or 10.**1.5
iter_step = 100

plt.subplot(1, 2, 1)
names =  ['Universal Similar Triangles', 'Universal Gradient Method', 'Subgradient Method']
methods = ['ustf', 'ugd', 'sd']
for index in range(len(methods)):
    result = results[(methods[index], eps_abs)]
    y = result['dual_func_history'][::iter_step] - dual_min
    x = iter_step * np.arange(len(y))
    plt.plot(x, y, label=names[index])
plt.legend(title = 'eps_abs = 31.6')
plt.ylabel('|dual function - dual_min|')
plt.xlabel('iterations')

plt.subplot(1, 2, 2)
for index in range(len(methods)):
    result = results[(methods[index], eps_abs)]
    y = result['dual_func_history'][::iter_step] - dual_min
    x = iter_step * np.arange(len(y))
    plt.plot(x, y, label=names[index])
plt.legend(title = 'eps_abs = 31.6')
plt.ylabel('|dual function - dual_min|')
plt.xlabel('iterations')
plt.yscale('log')

#plt.savefig('methods_stable_dynamic.png')
plt.show()

# %%
plt.figure(figsize=(7.5,6))
eps_abs_name = '31.6'

start = 100 #!!!!!!!
iter_step = 50
for eps_abs in np.logspace(1,3,5)[[1]]:
    result = results[('ustf', eps_abs)]
    y = - np.array(result['dual_func_history'])[start::iter_step]
    x = start + iter_step * np.arange(len(y))
    plt.plot(x, y, label='dual')
    y = result['primal_func_history'][start::iter_step]
    x = start + iter_step * np.arange(len(y))
    plt.plot(x, y, label='primal')
plt.legend(title = 'eps_abs = '+ eps_abs_name)
plt.xlabel('iterations')
plt.title('Universal Similar Triangles')

#plt.savefig('duality_gap_stable_dynamic.png')
plt.show()

# %% [markdown]
# # Beckman's model experiments

# %%
results = {}
eps_list = np.logspace(1,3,5)[0:2]

max_iter = 10000
with open('anaheim_result_' + 'fwa' + '_max_iter_' + str(max_iter) + 
          '_Beckman.pickle', 'rb') as f:
    result = pickle.load(f)
    results[('fwa', None)] = result
for i, eps_abs in enumerate(eps_list):
    with open('anaheim_result_' + 'ustf' +  '_#' + str(i) + '_max_iter_' + str(max_iter) + 
              '_Beckman.pickle', 'rb') as f:
        result = pickle.load(f)
        results[('ustf', eps_abs)] = result
for i, eps_abs in enumerate(eps_list):
    with open('anaheim_result_' + 'ugd' + '_#' + str(i) + '_max_iter_' + str(max_iter) + 
              '_Beckman.pickle', 'rb') as f:
        result = pickle.load(f)
        results[('ugd', eps_abs)] = result
for i, eps_abs in enumerate(eps_list ):
    with open('anaheim_result_' + 'sd' + '_#' + str(i) + '_max_iter_' + str(max_iter) + 
              '_Beckman.pickle', 'rb') as f:
        result = pickle.load(f)
        results[('sd', eps_abs)] = result

# %%
dual_min = np.inf
for pair, result in results.items():
    if pair[0] != 'fwa':
        dual_min = min(dual_min, np.min(result['dual_func_history']))
print(dual_min )
# Out:
# -1205590.6954066206

# %%
plt.figure(figsize=(15,6))
iter_step = 100
method = 'ustf'
plt.suptitle('Universal Similar Triangles', fontsize=20)

plt.subplot(1, 2, 1)
for i, eps_abs in enumerate(eps_list):
    result = results[(method, eps_abs)]
    y = result['dual_func_history'][::iter_step] - dual_min
    x = iter_step * np.arange(len(y))
    plt.plot(x, y, label=str(eps_abs))
plt.legend(title="eps_abs")
plt.ylabel('|dual function - dual_min|')
plt.xlabel('iterations')

plt.subplot(1, 2, 2)
for i, eps_abs in enumerate(eps_list):
    result = results[(method, eps_abs)]
    y = result['dual_func_history'][::iter_step] - dual_min
    x = iter_step * np.arange(len(y))
    plt.plot(x, y, label=str(eps_abs))
plt.legend(title="eps_abs")
plt.yscale('log')
plt.ylabel('|dual function - dual_min|')
plt.xlabel('iterations')

#plt.savefig('ustm_beckman.png')
plt.show()

# %%
plt.figure(figsize=(7.5,6))
eps_abs = eps_list[1] # or 10.**1.5
print('eps_abs = ', eps_abs)
iter_step = 100
start = 0
end = 1000

names =  ['Universal Similar Triangles', 'Universal Gradient Method', 'Subgradient Method', 'Frank-Wolfe algorithm']
methods = ['ustf', 'ugd', 'sd', 'fwa']
for index in range(len(methods)):
    if methods[index] == 'fwa':
        result = results[(methods[index], None)]
    else:
        result = results[(methods[index], eps_abs)]
    y = result['primal_func_history'][::iter_step]
    x =iter_step * np.arange(len(y))
    plt.plot(x, y, label=names[index])
plt.legend(title = 'eps_abs = 31.6')
plt.ylabel('primal function')
plt.xlabel('iterations')

#plt.savefig('methods_beckman.png')
plt.show()
# Out:
# eps_abs =  31.622776601683793

# %%
plt.figure(figsize=(7.5,6))
eps_abs_name = '31.6'

start = 100 #!!!!!!!
iter_step = 50
for eps_abs in np.logspace(1,3,5)[[1]]:
    result = results[('ustf', eps_abs)]
    y = - np.array(result['dual_func_history'])[start::iter_step]
    x = start + iter_step * np.arange(len(y))
    plt.plot(x, y, label='dual')
    y = result['primal_func_history'][start::iter_step]
    x = start + iter_step * np.arange(len(y))
    plt.plot(x, y, label='primal')
plt.legend(title = 'eps_abs = '+ eps_abs_name)
plt.yscale('log')
plt.xlabel('iterations')
plt.title('Universal Similar Triangles')

#plt.savefig('duality_gap_beckman.png')
plt.show()

# %% [markdown]
# ### experiments end here

# %% [markdown]
# something below

# %%
model.mu = 0

solver_kwargs = {'eps': 1e-2,
                 'eps_abs': 5,
                 'max_iter': 1000}

tic = time.time()
result = model.find_equilibrium(solver_name = 'ustf', solver_kwargs = solver_kwargs, verbose = True)
toc = time.time()
print('Elapsed time: {:.0f} sec'.format(toc - tic))
flows.append(result['flows'])
times.append(result['times'])
iter_nums.append(result['iter_num'])
primal_vals.append(result['primal_func_history'])
dual_vals.append(result['dual_func_history'])
# Out:
# Oracles created...
# Universal similar triangles function...
# Primal_init = 1.17521e+06
# Dual_init = -1.17025e+06
# Duality_gap_init = 4964.56
#
# Iterations number: 1
# Inner iterations number: 1
# Primal_func_value = 1.17521e+06
# Dual_func_value = -1.17025e+06
# Duality_gap = 4964.56
# Duality_gap / Duality_gap_init = 1
#
# Iterations number: 100
# Inner iterations number: 2
# Primal_func_value = 1.1737e+06
# Dual_func_value = -1.1736e+06
# Duality_gap = 105.992
# Duality_gap / Duality_gap_init = 0.0213497
#
# Iterations number: 200
# Inner iterations number: 1
# Primal_func_value = 1.1737e+06
# Dual_func_value = -1.17363e+06
# Duality_gap = 69.6016
# Duality_gap / Duality_gap_init = 0.0140197
#
# Iterations number: 300
# Inner iterations number: 1
# Primal_func_value = 1.17369e+06
# Dual_func_value = -1.17364e+06
# Duality_gap = 51.3706
# Duality_gap / Duality_gap_init = 0.0103475
#
# Iterations number: 400
# Inner iterations number: 2
# Primal_func_value = 1.17368e+06
# Dual_func_value = -1.17364e+06
# Duality_gap = 34.2027
# Duality_gap / Duality_gap_init = 0.00688937
#
# Iterations number: 500
# Inner iterations number: 1
# Primal_func_value = 1.17368e+06
# Dual_func_value = -1.17365e+06
# Duality_gap = 28.1803
# Duality_gap / Duality_gap_init = 0.00567628
#
# Iterations number: 600
# Inner iterations number: 3
# Primal_func_value = 1.17367e+06
# Dual_func_value = -1.17365e+06
# Duality_gap = 20.012
# Duality_gap / Duality_gap_init = 0.00403097
#
# Iterations number: 700
# Inner iterations number: 2
# Primal_func_value = 1.17367e+06
# Dual_func_value = -1.17366e+06
# Duality_gap = 15.2485
# Duality_gap / Duality_gap_init = 0.00307146
#
# Iterations number: 800
# Inner iterations number: 2
# Primal_func_value = 1.17367e+06
# Dual_func_value = -1.17366e+06
# Duality_gap = 10.6392
# Duality_gap / Duality_gap_init = 0.00214302
#
# Iterations number: 900
# Inner iterations number: 4
# Primal_func_value = 1.17367e+06
# Dual_func_value = -1.17366e+06
# Duality_gap = 8.61065
# Duality_gap / Duality_gap_init = 0.00173442
#
# Iterations number: 1000
# Inner iterations number: 1
# Primal_func_value = 1.17367e+06
# Dual_func_value = -1.17366e+06
# Duality_gap = 6.48332
# Duality_gap / Duality_gap_init = 0.00130592
#
# Iterations number exceeded!
# Primal_func_value = 1.17367e+06
# Duality_gap / Duality_gap_init = 0.00130592
# Phi_big_oracle elapsed time: 422 sec
# Elapsed time: 424 sec

# %%
plt.plot(np.arange(len(dual_vals[-1])), dual_vals[-1] - np.min(dual_vals[-1]), label='dual')
plt.plot(np.arange(len(primal_vals[-1])), primal_vals[-1] - np.min(primal_vals[-1]), label='primal')
plt.plot(np.arange(len(result['duality_gap_history'])), 
         result['duality_gap_history'] - np.min(result['duality_gap_history']), 
         label='duality gap')

plt.legend()
plt.yscale('log')
plt.show()

# %%
flows = []
times = []
iter_nums = []
primal_vals = []
dual_vals = []

model.mu = 0
solver_kwargs = {'eps': 1e-2,
                 'eps_abs': 1000,
                 'max_iter': 200,
                 'L_init': None}

tic = time.time()
result = model.find_equilibrium(solver_name = 'ustf', solver_kwargs = solver_kwargs, verbose = True)
toc = time.time()
print('Elapsed time: {:.0f} sec'.format(toc - tic))
flows.append(result['flows'])
times.append(result['times'])
iter_nums.append(result['iter_num'])
primal_vals.append(result['primal_func_history'])
dual_vals.append(result['dual_func_history'])
# Out:
# Oracles created...
# Universal similar triangles function...
# Primal_init = 1.16926e+06
# Dual_init = -1.16951e+06
# Duality_gap_init = 7.41849e+08
#
# Iterations number: 1
# Inner iterations number: 1
# Primal_func_value = 1.16926e+06
# Dual_func_value = -1.16951e+06
# Duality_gap = 7.41849e+08
# Duality_gap / Duality_gap_init = 1
#
# Iterations number: 10
# Inner iterations number: 1
# Primal_func_value = 1.1713e+06
# Dual_func_value = -1.17232e+06
# Duality_gap = 3.61408e+08
# Duality_gap / Duality_gap_init = 0.487171
#
# Iterations number: 20
# Inner iterations number: 2
# Primal_func_value = 1.17228e+06
# Dual_func_value = -1.17282e+06
# Duality_gap = 1.81349e+08
# Duality_gap / Duality_gap_init = 0.244455
#
# Iterations number: 30
# Inner iterations number: 3
# Primal_func_value = 1.17244e+06
# Dual_func_value = -1.17294e+06
# Duality_gap = 1.24874e+08
# Duality_gap / Duality_gap_init = 0.168327
#
# Iterations number: 40
# Inner iterations number: 1
# Primal_func_value = 1.17261e+06
# Dual_func_value = -1.17294e+06
# Duality_gap = 8.32656e+07
# Duality_gap / Duality_gap_init = 0.112241
#
# Iterations number: 50
# Inner iterations number: 1
# Primal_func_value = 1.17274e+06
# Dual_func_value = -1.17293e+06
# Duality_gap = 7.2946e+07
# Duality_gap / Duality_gap_init = 0.09833
#
# Iterations number: 60
# Inner iterations number: 1
# Primal_func_value = 1.17276e+06
# Dual_func_value = -1.17296e+06
# Duality_gap = 7.34025e+07
# Duality_gap / Duality_gap_init = 0.0989453
#
# Iterations number: 70
# Inner iterations number: 2
# Primal_func_value = 1.1728e+06
# Dual_func_value = -1.17296e+06
# Duality_gap = 4.96541e+07
# Duality_gap / Duality_gap_init = 0.0669329
#
# Iterations number: 80
# Inner iterations number: 1
# Primal_func_value = 1.17279e+06
# Dual_func_value = -1.17296e+06
# Duality_gap = 4.24683e+07
# Duality_gap / Duality_gap_init = 0.0572466
#
# Iterations number: 90
# Inner iterations number: 1
# Primal_func_value = 1.1728e+06
# Dual_func_value = -1.17296e+06
# Duality_gap = 4.38411e+07
# Duality_gap / Duality_gap_init = 0.0590971
#
# Iterations number: 100
# Inner iterations number: 2
# Primal_func_value = 1.17285e+06
# Dual_func_value = -1.17297e+06
# Duality_gap = 2.86497e+07
# Duality_gap / Duality_gap_init = 0.0386192
#
# Iterations number: 110
# Inner iterations number: 3
# Primal_func_value = 1.17286e+06
# Dual_func_value = -1.17297e+06
# Duality_gap = 3.77719e+07
# Duality_gap / Duality_gap_init = 0.0509159
#
# Iterations number: 120
# Inner iterations number: 4
# Primal_func_value = 1.17286e+06
# Dual_func_value = -1.17297e+06
# Duality_gap = 3.42419e+07
# Duality_gap / Duality_gap_init = 0.0461575
#
# Iterations number: 130
# Inner iterations number: 2
# Primal_func_value = 1.17286e+06
# Dual_func_value = -1.17296e+06
# Duality_gap = 2.63751e+07
# Duality_gap / Duality_gap_init = 0.0355532
#
# Iterations number: 140
# Inner iterations number: 3
# Primal_func_value = 1.17287e+06
# Dual_func_value = -1.17298e+06
# Duality_gap = 2.8375e+07
# Duality_gap / Duality_gap_init = 0.0382491
#
# Iterations number: 150
# Inner iterations number: 3
# Primal_func_value = 1.1729e+06
# Dual_func_value = -1.17297e+06
# Duality_gap = 2.21141e+07
# Duality_gap / Duality_gap_init = 0.0298094
#
# Iterations number: 160
# Inner iterations number: 5
# Primal_func_value = 1.17289e+06
# Dual_func_value = -1.17297e+06
# Duality_gap = 2.50103e+07
# Duality_gap / Duality_gap_init = 0.0337135
#
# Iterations number: 170
# Inner iterations number: 3
# Primal_func_value = 1.1729e+06
# Dual_func_value = -1.17297e+06
# Duality_gap = 2.08525e+07
# Duality_gap / Duality_gap_init = 0.0281089
#
# Iterations number: 180
# Inner iterations number: 3
# Primal_func_value = 1.17291e+06
# Dual_func_value = -1.17297e+06
# Duality_gap = 1.88272e+07
# Duality_gap / Duality_gap_init = 0.0253788
#
# Iterations number: 190
# Inner iterations number: 2
# Primal_func_value = 1.17291e+06
# Dual_func_value = -1.17297e+06
# Duality_gap = 2.02806e+07
# Duality_gap / Duality_gap_init = 0.0273379
#
# Iterations number: 200
# Inner iterations number: 1
# Primal_func_value = 1.17292e+06
# Dual_func_value = -1.17297e+06
# Duality_gap = 1.40136e+07
# Duality_gap / Duality_gap_init = 0.01889
#
# Iterations number exceeded!
# Primal_func_value = 1.17292e+06
# Duality_gap / Duality_gap_init = 0.01889
# Phi_big_oracle elapsed time: 68 sec
# Elapsed time: 68 sec

# %%
print(np.max(times[0] / graph_data['graph_table']['Free Flow Time']))
print(np.max(flows[0] / graph_data['graph_table']['Capacity']) - 1)
# Out:
# 2.8770743805778567
# 0.009583812343949116

# %%
with open('anaheim_result_ustf_1e-3.pickle', 'wb') as f:
    pickle.dump(result, f)

# %% [markdown]
# ### end for stable dynamic

# %% [markdown]
# ### For Beckman's model:

# %%
model.mu = 0.25
max_iter = 10000
for i, eps_abs in enumerate(np.logspace(1,3,5)):
    print('eps_abs =', eps_abs)
    solver_kwargs = {'eps_abs': eps_abs,
                     'max_iter': max_iter}
    tic = time.time()
    result = model.find_equilibrium(solver_name = 'ustf', solver_kwargs = solver_kwargs, verbose = False)
    toc = time.time()
    print('Elapsed time: {:.0f} sec'.format(toc - tic))
    
    print('Time ratio =', np.max(result['times'] / graph_data['graph_table']['Free Flow Time']))
    print('Flow excess =', np.max(result['flows'] / graph_data['graph_table']['Capacity']) - 1, end = '\n\n')
    
    result['eps_abs'] = eps_abs
    with open('anaheim_result_' + 'ustf' + '_#' + str(i) + '_max_iter_' + str(max_iter) + 
              '_Beckman.pickle', 'wb') as f:
        pickle.dump(result, f)
# Out:
# eps_abs = 10.0
# Elapsed time: 3405 sec
# Time ratio = 2.9084886191164783
# Flow excess = 0.8891944444444437
#
# eps_abs = 31.622776601683793
# Elapsed time: 3523 sec
# Time ratio = 2.9107237309389733
# Flow excess = 0.8891944444444417
#
# eps_abs = 100.0
# Elapsed time: 3570 sec
# Time ratio = 2.9107237337628917
# Flow excess = 0.8891944444444415
#
# eps_abs = 316.22776601683796
# Elapsed time: 3552 sec
# Time ratio = 2.9107237337629024
# Flow excess = 0.8891944444444448
#
# eps_abs = 1000.0
# /home/mk/Meruza/TransportNet/TransportNet-Nash-Wardrop_equilibrium_2019/universal_similar_triangles_function.py:65: RuntimeWarning: invalid value encountered in true_divide
#   y = (alpha * u_prev + A_prev * t_prev) / A
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-188f13c0a314> in <module>()
#       6                      'max_iter': max_iter}
#       7     tic = time.time()
# ----> 8     result = model.find_equilibrium(solver_name = 'ustf', solver_kwargs = solver_kwargs, verbose = False)
#       9     toc = time.time()
#      10     print('Elapsed time: {:.0f} sec'.format(toc - tic))
#
# ~/Meruza/TransportNet/TransportNet-Nash-Wardrop_equilibrium_2019/model.py in find_equilibrium(self, solver_name, solver_kwargs, verbose)
#      57                              primal_dual_calculator,
#      58                              t_start = self.graph.freeflow_times,
# ---> 59                              verbose = verbose, **solver_kwargs)
#      60
#      61         return result
#
# ~/Meruza/TransportNet/TransportNet-Nash-Wardrop_equilibrium_2019/universal_similar_triangles_function.py in universal_similar_triangles_function(phi_big_oracle, prox_h, primal_dual_oracle, t_start, L_init, max_iter, crit_name, eps, eps_abs, verbose)
#      64
#      65             y = (alpha * u_prev + A_prev * t_prev) / A
# ---> 66             phi_grad_y = phi_big_oracle.grad(y)
#      67             grad_sum = grad_sum_prev + alpha * phi_grad_y
#      68             u = prox_h(y_start - grad_sum, A, u_start = u_prev)
#
# ~/Meruza/TransportNet/TransportNet-Nash-Wardrop_equilibrium_2019/oracles.py in grad(self, t_parameter)
#     135         self.grad_current = np.zeros(self.graph.links_number)
#     136         for auto_oracle in self.auto_oracles:
# --> 137             self.grad_current += auto_oracle.grad(self.t_current)
#     138         self.time += time.time() - tic
#     139         return self.grad_current
#
# ~/Meruza/TransportNet/TransportNet-Nash-Wardrop_equilibrium_2019/oracles.py in grad(self, t_parameter)
#      79         pred_edges = [self.graph.pred_to_edge[vertex][self.pred_map[vertex]] for vertex in sorted_vertices]
#      80         flows = get_flows(self.graph.nodes_number, self.graph.links_number,
# ---> 81                           self.corr_targets, self.corr_values, self.pred_map, pred_edges, sorted_vertices)
#      82         return - flows
#      83
#
# ValueError: cannot compute fingerprint of empty list

# %%
model.mu = 0.25
max_iter = 10000
for i, eps_abs in enumerate(np.logspace(1,3,5)[0:2]):
    print('eps_abs =', eps_abs)
    solver_kwargs = {'eps_abs': eps_abs,
                     'max_iter': max_iter}
    tic = time.time()
    result = model.find_equilibrium(solver_name = 'ugd', solver_kwargs = solver_kwargs, verbose = False)
    toc = time.time()
    print('Elapsed time: {:.0f} sec'.format(toc - tic))
    
    print('Time ratio =', np.max(result['times'] / graph_data['graph_table']['Free Flow Time']))
    print('Flow excess =', np.max(result['flows'] / graph_data['graph_table']['Capacity']) - 1, end = '\n\n')
    
    result['eps_abs'] = eps_abs
    with open('anaheim_result_' + 'ugd' + '_#' + str(i) + '_max_iter_' + str(max_iter) + 
              '_Beckman.pickle', 'wb') as f:
        pickle.dump(result, f)
# Out:
# eps_abs = 10.0
# Elapsed time: 2800 sec
# Time ratio = 2.3778826569074134
# Flow excess = 1.3612209136725588
#
# eps_abs =

# %%
model.mu = 0.25
max_iter = 10000
for i, eps_abs in enumerate(np.logspace(1,3,5)[0:2]):
    print('eps_abs =', eps_abs)
    solver_kwargs = {'eps_abs': eps_abs,
                     'max_iter': max_iter}
    tic = time.time()
    result = model.find_equilibrium(solver_name = 'sd', solver_kwargs = solver_kwargs, verbose = False)
    toc = time.time()
    print('Elapsed time: {:.0f} sec'.format(toc - tic))
    
    print('Time ratio =', np.max(result['times'] / graph_data['graph_table']['Free Flow Time']))
    print('Flow excess =', np.max(result['flows'] / graph_data['graph_table']['Capacity']) - 1, end = '\n\n')
    
    result['eps_abs'] = eps_abs
    with open('anaheim_result_' + 'sd' + '_#' + str(i) + '_max_iter_' + str(max_iter) + 
              '_Beckman.pickle', 'wb') as f:
        pickle.dump(result, f)

# %% [markdown]
# ### experiments for Beckman model ends here.

# %% [markdown]
# #### flows_ star

# %%
with open('anaheim_result_fwa_3e-5.pickle', 'rb') as f:
    result_star = pickle.load(f)
    flow_star = result_star['flows']
    primal = result_star['primal_func_history']

# %%
primal
# Out:
# [1264518.0671581021,
#  1222181.0009921354,
#  1218451.4155435765,
#  1212523.4279154581,
#  1211034.901107549,
#  1209121.9098656217,
#  1208313.1420744851,
#  1207757.8685086381,
#  1207297.5174920973,
#  1206918.6446882756,
#  1206847.2436235324,
#  1206662.476528934,
#  1206431.7150182617,
#  1206323.032232082,
#  1206226.647595041,
#  1206186.8848818541,
#  1206103.1204818855,
#  1206063.7078061434,
#  1206032.3079034777,
#  1205991.9777502944,
#  1205939.6746319132,
#  1205914.5045358799,
#  1205888.1942881709,
#  1205851.2875879216,
#  1205836.1984073576,
#  1205827.3614231409,
#  1205796.5112790598,
#  1205777.0014084242,
#  1205778.6549308151,
#  1205778.4582665353,
#  1205756.269613351,
#  1205745.5340009648,
#  1205731.6602954632,
#  1205726.1722821968,
#  1205715.2955188472,
#  1205712.4061292293,
#  1205713.6129185027,
#  1205714.604102795,
#  1205698.0652911703,
#  1205690.0660038169,
#  1205681.4841722897,
#  1205680.4975781851,
#  1205673.4350094434,
#  1205673.8615528282,
#  1205668.123427246,
#  1205662.0714706376,
#  1205661.4303098335,
#  1205661.3315272464,
#  1205655.9374816795,
#  1205652.2215121449,
#  1205654.5436605038,
#  1205650.6240253923,
#  1205647.2114319568,
#  1205645.6318708567,
#  1205643.2432040463,
#  1205640.3320661986,
#  1205638.0978740519,
#  1205637.1106727002,
#  1205637.1138051534,
#  1205633.9828269985,
#  1205634.0746305147,
#  1205631.3086879146,
#  1205629.6300114577,
#  1205627.7099549854,
#  1205626.6306766968,
#  1205628.0971710845,
#  1205625.9323377078,
#  1205624.8164156899,
#  1205624.5106557717,
#  1205622.2463113277,
#  1205622.240032461,
#  1205620.1034212438,
#  1205619.9355734277,
#  1205619.6189320569,
#  1205620.0166257301,
#  1205618.041647404,
#  1205616.8028654768,
#  1205617.1978837007,
#  1205615.9065211692,
#  1205614.913258234,
#  1205614.2268569637,
#  1205613.4745065216,
#  1205613.0060299588,
#  1205612.4036352246,
#  1205613.9084228734,
#  1205613.75070024,
#  1205612.0849134852,
#  1205610.9477997795,
#  1205610.4342411787,
#  1205609.8284536111,
#  1205609.4115752862,
#  1205610.0954686259,
#  1205609.0565524371,
#  1205607.9016036652,
#  1205609.8372739991,
#  1205608.6987250457,
#  1205607.2406881307,
#  1205607.1403886226,
#  1205607.5085509387,
#  1205606.991741254,
#  1205606.5946693697,
#  1205607.5789380763,
#  1205605.8887744891,
#  1205605.3318880196,
#  1205605.6088950033,
#  1205606.3992599987,
#  1205605.2523803927,
#  1205604.5282854009,
#  1205604.014355388,
#  1205603.7155452652,
#  1205603.3691182709,
#  1205603.7643929888,
#  1205602.8941862136,
#  1205603.5717468779,
#  1205603.1621767187,
#  1205602.5135552005,
#  1205602.2128882173,
#  1205602.281862586,
#  1205602.4947314046,
#  1205602.0388899236,
#  1205601.310482614,
#  1205601.1195203001,
#  1205601.2045544102,
#  1205601.357933609,
#  1205601.4762746091,
#  1205601.168541884,
#  1205600.7518022051,
#  1205600.5862820009,
#  1205600.5689089417,
#  1205600.0850165619,
#  1205599.8835776176,
#  1205599.6829528755,
#  1205599.348372011,
#  1205599.5780837475,
#  1205599.8238123406,
#  1205599.1863625217,
#  1205598.8916740445,
#  1205598.88806913,
#  1205598.7569523966,
#  1205598.9700265401,
#  1205598.510602246,
#  1205598.9962042961,
#  1205598.6342963157,
#  1205598.911464443,
#  1205598.6460543699,
#  1205598.3141381629,
#  1205598.2382165957,
#  1205597.915753372,
#  1205597.7570200181,
#  1205597.8322643817,
#  1205598.1000109841,
#  1205597.6489031184,
#  1205597.3501776271,
#  1205597.148114867,
#  1205597.386962665,
#  1205597.2589375032,
#  1205597.2169567272,
#  1205597.5998683383,
#  1205597.0441732639,
#  1205597.016254893,
#  1205596.6492801588,
#  1205596.7924153153,
#  1205596.9048538283,
#  1205596.8926630467,
#  1205596.7381209768,
#  1205597.1685998146,
#  1205596.8168669976,
#  1205596.4559953385,
#  1205596.5226034371,
#  1205596.1812249837,
#  1205596.1855841847,
#  1205596.3619481099,
#  1205596.4900348452,
#  1205596.105007079,
#  1205596.0991748497,
#  1205596.1349020025,
#  1205595.9404396305,
#  1205595.6759339783,
#  1205595.7266168885,
#  1205595.6287344547,
#  1205595.4095361121,
#  1205595.3516250176,
#  1205595.7147815325,
#  1205595.4845358399,
#  1205595.3582297629,
#  1205595.2495950293,
#  1205595.1766507353,
#  1205595.1623882609,
#  1205594.9968311205,
#  1205595.0913493338,
#  1205595.1802654385,
#  1205594.9613102747,
#  1205595.0707946401,
#  1205595.0493656187,
#  1205594.8292434965,
#  1205594.7370357236,
#  1205594.9960338701,
#  1205594.8637279496,
#  1205594.6427032952,
#  1205594.8787631306,
#  1205594.619201316,
#  1205594.6020915469,
#  1205594.7357809446,
#  1205594.692155512,
#  1205594.5266833887,
#  1205594.4373911035,
#  1205594.3599813022,
#  1205594.2560115031,
#  1205594.4989770385,
#  1205594.599369396,
#  1205594.2968500585,
#  1205594.2196275988,
#  1205594.5562091318,
#  1205594.3032636319,
#  1205594.1099633176,
#  1205594.0932828116,
#  1205594.2497321782,
#  1205594.0739283175,
#  1205594.0125479037,
#  1205594.296619023,
#  1205594.3125933248,
#  1205594.0171804526,
#  1205593.9321807239,
#  1205593.8683596863,
#  1205593.8257746589,
#  1205593.7047682581,
#  1205593.9359047031,
#  1205593.9299513078,
#  1205593.7728064337,
#  1205593.8272339161,
#  1205593.8290820795,
#  1205593.7006841938,
#  1205593.6967657665,
#  1205593.5716547058,
#  1205593.6887852622,
#  1205593.5291781197,
#  1205593.4545641984,
#  1205593.6072998573,
#  1205593.4867163226,
#  1205593.3908548574,
#  1205593.7552772844,
#  1205593.4766293105,
#  1205593.3080847254,
#  1205593.2987857503,
#  1205593.4633152131,
#  1205593.3467332378,
#  1205593.3227102619,
#  1205593.2238255595,
#  1205593.5075192754,
#  1205593.3376221014,
#  1205593.2061851854,
#  1205593.3756463928,
#  1205593.3973982469,
#  1205593.277225018,
#  1205593.2360543341,
#  1205593.1314461899,
#  1205593.1021236726,
#  1205593.0428626798,
#  1205592.9954254159,
#  1205593.0364962069,
#  1205592.9724019584,
#  1205593.0442737287,
#  1205593.0313424263,
#  1205593.0757043245,
#  1205592.9614511419,
#  1205592.8421025777,
#  1205592.930075136,
#  1205592.9437473998,
#  1205593.085735321,
#  1205593.0345284985,
#  1205592.8754028492,
#  1205592.9054368131,
#  1205592.7815493457,
#  1205592.9435440274,
#  1205592.7959199187,
#  1205592.6999301524,
#  1205592.7781376299,
#  1205592.7715053305,
#  1205592.6973609123,
#  1205592.7508451266,
#  1205592.8292823266,
#  1205592.7407879347,
#  1205592.7110361082,
#  1205592.6413622836,
#  1205592.7618864202,
#  1205592.7170007012,
#  1205592.7091041221,
#  1205592.7709448047,
#  1205592.7737387873,
#  1205592.6757796765,
#  1205592.6756598593,
#  1205592.718295007,
#  1205592.5781167885,
#  1205592.5224256946,
#  1205592.53304009,
#  1205592.4944940533,
#  1205592.4408850265,
#  1205592.5931167929,
#  1205592.501946588,
#  1205592.4967835911,
#  1205592.451301923,
#  1205592.4549065523,
#  1205592.466690629,
#  1205592.4211639203,
#  1205592.3568391926,
#  1205592.4526140741,
#  1205592.3772097663,
#  1205592.3492911193,
#  1205592.3522433951,
#  1205592.3598307571,
#  1205592.2873294738,
#  1205592.3154954563,
#  1205592.3126979051,
#  1205592.2732279357,
#  1205592.3757944261,
#  1205592.2889414923,
#  1205592.3614587656,
#  1205592.3176515386,
#  1205592.226521271,
#  1205592.3926406838,
#  1205592.2638244382,
#  1205592.1769506852,
#  1205592.247866356,
#  1205592.2436696808,
#  1205592.212450956,
#  1205592.2386389244,
#  1205592.2134455077,
#  1205592.3150108042,
#  1205592.2771672523,
#  1205592.2071117058,
#  1205592.1982953418,
#  1205592.1430020323,
#  1205592.2257254666,
#  1205592.1541778727,
#  1205592.0751680811,
#  1205592.1375296272,
#  1205592.0727885535,
#  1205592.0642200243,
#  1205592.15916113,
#  1205592.0994130666,
#  1205592.0285288738,
#  1205592.1243255571,
#  1205592.0371397773,
#  1205592.0150156189,
#  1205591.9822879843,
#  1205592.0297377044,
#  1205592.06894641,
#  1205592.0152494402,
#  1205592.0027276787,
#  1205591.9572581048,
#  1205591.9589368757,
#  1205592.0072138095,
#  1205592.049777363,
#  1205591.9898861053,
#  1205591.9606452074,
#  1205591.9865407441,
#  1205591.9831853705,
#  1205591.9564773403,
#  1205591.9044975305,
#  1205591.9155395576,
#  1205591.9866517282,
#  1205592.0018953597,
#  1205591.9616016401,
#  1205591.9502617219,
#  1205591.9148589461,
#  1205592.0029968699,
#  1205591.8995836652,
#  1205591.8863293189,
#  1205591.8374313281]

# %%
with open('anaheim_result_ustf_1e-3.pickle', 'rb') as f:
    result = pickle.load(f)
    flow = result['flows']

# %%
delta = np.linalg.norm(flow - flow_star, ord = 1) / np.linalg.norm(flow_star, ord = 1)
delta
# Out:
# 0.3868623683178405

# %%
epsilon = 1e-3
plt.rc('text', usetex = True)
#plt.font = {'family': 'Verdana', 'weight': 'normal'}
#plt.rc('font', **font)
plt.plot(gammas, delta, 'black')
plt.title(r'$\epsilon = 10^{-3}$')
plt.xlabel(r'$\gamma$')
plt.ylabel(r'$\|f - f^*\|_1 / \|f^* \|$')
#plt.savefig('anaheim_delta_vs_gamma_{0:.0e}_withouty.png'.format(epsilon), dpi=300)
plt.show()

# %% [markdown]
# ## Experiment 2  comparing USTF and UGD

# %%
epsilons = np.logspace(-1, -2, 10)[::-1]
epsilons
# Out:
# array([ 0.01      ,  0.0129155 ,  0.01668101,  0.02154435,  0.02782559,
#         0.03593814,  0.04641589,  0.05994843,  0.07742637,  0.1       ])

# %%
iter_nums_for_epsilons = []
exec_times_for_epsilons = []
flows = []
duality_gap_histories = []

for epsilon in epsilons:
    tic = time.time()
    print('epsilon = ' + str(epsilon))
    result = model.model_solve(graph, graph_correspondences, total_od_flow,
                               solver_name = 'ustf',
                               mu = 0.25, rho = 0.15, epsilon = epsilon,
                               max_iter = 5000, verbose = True)
    toc = time.time()
    print('Elapsed time: {:.0f} sec'.format(toc - tic))
    exec_times_for_epsilons.append(toc - tic)
    iter_nums_for_epsilons.append(result['iter_num'])
    flows.append(result['flows'])
    duality_gap_histories.append(result['duality_gap_history'])
# Out:
# epsilon = 0.01
# Oracles created...
# Universal similar triangles function...
# primal_init = 1264518.06716
# dual_init = -1170970.03287
# duality_gap_init = 93548.0342887
# Iterations number: 1
# Dual_gap_value = 93548.0342887
# primal_func_value = 1264518.06716
# Duality_gap / Duality_gap_init = 1.0
# Iterations number: 5
# Dual_gap_value = 68662.7943418
# primal_func_value = 1253316.63483
# Duality_gap / Duality_gap_init = 0.733984362834
# iteration_num = 8: L_value = 31038.071462318658
# iteration_num = 9: L_value = 31038.071462318658
# iteration_num = 9: L_value = 62076.142924637315
# iteration_num = 9: L_value = 124152.28584927463
# Iterations number: 10
# Dual_gap_value = 9696.98055771
# primal_func_value = 1208953.96847
# Duality_gap / Duality_gap_init = 0.10365776931
# iteration_num = 12: L_value = 31038.071462318658
# iteration_num = 12: L_value = 62076.142924637315
# iteration_num = 13: L_value = 62076.142924637315
# iteration_num = 13: L_value = 124152.28584927463
# iteration_num = 15: L_value = 62076.142924637315
# iteration_num = 15: L_value = 124152.28584927463
# Iterations number: 15
# Dual_gap_value = 4758.87892735
# primal_func_value = 1207320.65972
# Duality_gap / Duality_gap_init = 0.0508709665952
# iteration_num = 17: L_value = 62076.142924637315
# iteration_num = 18: L_value = 62076.142924637315
# iteration_num = 18: L_value = 124152.28584927463
# iteration_num = 18: L_value = 248304.57169854926
# iteration_num = 20: L_value = 124152.28584927463
# Iterations number: 20
# Dual_gap_value = 2780.29814155
# primal_func_value = 1206536.82039
# Duality_gap / Duality_gap_init = 0.0297205404976
# iteration_num = 21: L_value = 124152.28584927463
# iteration_num = 23: L_value = 62076.142924637315
# iteration_num = 23: L_value = 124152.28584927463
# iteration_num = 25: L_value = 62076.142924637315
# Iterations number: 25
# Dual_gap_value = 1420.27703043
# primal_func_value = 1205875.25228
# Duality_gap / Duality_gap_init = 0.0151823289632
# iteration_num = 27: L_value = 31038.071462318658
# iteration_num = 28: L_value = 31038.071462318658
# iteration_num = 28: L_value = 62076.142924637315
# iteration_num = 28: L_value = 124152.28584927463
# iteration_num = 29: L_value = 124152.28584927463
# Success!  Iterations number: 30
# primal_func_value = 1205808.97731
# Duality_gap / Duality_gap_init = 0.00974483095545
# Phi big oracle elapsed time: 1044 sec
# Elapsed time: 1054 sec
# epsilon = 0.0129154966501
# Oracles created...
# Universal similar triangles function...
# primal_init = 1264518.06716
# dual_init = -1170970.03287
# duality_gap_init = 93548.0342887
# Iterations number: 1
# Dual_gap_value = 93548.0342887
# primal_func_value = 1264518.06716
# Duality_gap / Duality_gap_init = 1.0
# Iterations number: 5
# Dual_gap_value = 68662.7943418
# primal_func_value = 1253316.63483
# Duality_gap / Duality_gap_init = 0.733984362834
# iteration_num = 8: L_value = 31038.071462318658
# iteration_num = 9: L_value = 31038.071462318658
# iteration_num = 9: L_value = 62076.142924637315
# Iterations number: 10
# Dual_gap_value = 8521.9197624
# primal_func_value = 1208603.48825
# Duality_gap / Duality_gap_init = 0.091096727229
# iteration_num = 11: L_value = 31038.071462318658
# iteration_num = 11: L_value = 62076.142924637315
# iteration_num = 14: L_value = 15519.035731159329
# iteration_num = 14: L_value = 31038.071462318658
# iteration_num = 14: L_value = 62076.142924637315
# iteration_num = 14: L_value = 124152.28584927463
# Iterations number: 15
# Dual_gap_value = 3598.24860727
# primal_func_value = 1206937.96019
# Duality_gap / Duality_gap_init = 0.0384641819
# iteration_num = 17: L_value = 31038.071462318658
# iteration_num = 17: L_value = 62076.142924637315
# iteration_num = 17: L_value = 124152.28584927463
# iteration_num = 19: L_value = 62076.142924637315
# iteration_num = 20: L_value = 62076.142924637315
# Iterations number: 20
# Dual_gap_value = 1606.46116318
# primal_func_value = 1205962.46094
# Duality_gap / Duality_gap_init = 0.0171725806469
# iteration_num = 21: L_value = 62076.142924637315
# iteration_num = 22: L_value = 62076.142924637315
# iteration_num = 22: L_value = 124152.28584927463
# Success!  Iterations number: 24
# primal_func_value = 1205794.76094
# Duality_gap / Duality_gap_init = 0.0109807103755
# Phi big oracle elapsed time: 796 sec
# Elapsed time: 799 sec
# epsilon = 0.016681005372
# Oracles created...
# Universal similar triangles function...
# primal_init = 1264518.06716
# dual_init = -1170970.03287
# duality_gap_init = 93548.0342887
# Iterations number: 1
# Dual_gap_value = 93548.0342887
# primal_func_value = 1264518.06716
# Duality_gap / Duality_gap_init = 1.0
# Iterations number: 5
# Dual_gap_value = 68662.7943418
# primal_func_value = 1253316.63483
# Duality_gap / Duality_gap_init = 0.733984362834
# iteration_num = 8: L_value = 31038.071462318658
# iteration_num = 9: L_value = 31038.071462318658
# iteration_num = 9: L_value = 62076.142924637315
# Iterations number: 10
# Dual_gap_value = 8521.9197624
# primal_func_value = 1208603.48825
# Duality_gap / Duality_gap_init = 0.091096727229
# iteration_num = 11: L_value = 31038.071462318658
# iteration_num = 11: L_value = 62076.142924637315
# iteration_num = 14: L_value = 15519.035731159329
# iteration_num = 14: L_value = 31038.071462318658
# iteration_num = 14: L_value = 62076.142924637315
# iteration_num = 14: L_value = 124152.28584927463
# Iterations number: 15
# Dual_gap_value = 3598.24860727
# primal_func_value = 1206937.96019
# Duality_gap / Duality_gap_init = 0.0384641819
# iteration_num = 17: L_value = 31038.071462318658
# iteration_num = 17: L_value = 62076.142924637315
# iteration_num = 19: L_value = 31038.071462318658
# iteration_num = 19: L_value = 62076.142924637315
# Success!  Iterations number: 20
# primal_func_value = 1205927.55605
# Duality_gap / Duality_gap_init = 0.0158381507242
# Phi big oracle elapsed time: 646 sec
# Elapsed time: 649 sec
# epsilon = 0.0215443469003
# Oracles created...
# Universal similar triangles function...
# primal_init = 1264518.06716
# dual_init = -1170970.03287
# duality_gap_init = 93548.0342887
# Iterations number: 1
# Dual_gap_value = 93548.0342887
# primal_func_value = 1264518.06716
# Duality_gap / Duality_gap_init = 1.0
# Iterations number: 5
# Dual_gap_value = 68662.7943418
# primal_func_value = 1253316.63483
# Duality_gap / Duality_gap_init = 0.733984362834
# iteration_num = 9: L_value = 15519.035731159329
# iteration_num = 9: L_value = 31038.071462318658
# Iterations number: 10
# Dual_gap_value = 6643.68374381
# primal_func_value = 1208146.45968
# Duality_gap / Duality_gap_init = 0.0710189561366
# iteration_num = 11: L_value = 15519.035731159329
# iteration_num = 12: L_value = 15519.035731159329
# iteration_num = 12: L_value = 31038.071462318658
# iteration_num = 13: L_value = 31038.071462318658
# Success!  Iterations number: 15
# primal_func_value = 1205970.65358
# Duality_gap / Duality_gap_init = 0.0172968811693
# Phi big oracle elapsed time: 417 sec
# Elapsed time: 419 sec
# epsilon = 0.0278255940221
# Oracles created...
# Universal similar triangles function...
# primal_init = 1264518.06716
# dual_init = -1170970.03287
# duality_gap_init = 93548.0342887
# Iterations number: 1
# Dual_gap_value = 93548.0342887
# primal_func_value = 1264518.06716
# Duality_gap / Duality_gap_init = 1.0
# Iterations number: 5
# Dual_gap_value = 68662.7943418
# primal_func_value = 1253316.63483
# Duality_gap / Duality_gap_init = 0.733984362834
# iteration_num = 9: L_value = 15519.035731159329
# iteration_num = 10: L_value = 15519.035731159329
# Iterations number: 10
# Dual_gap_value = 6733.996832
# primal_func_value = 1208594.66968
# Duality_gap / Duality_gap_init = 0.0719843755479
# iteration_num = 11: L_value = 15519.035731159329
# iteration_num = 12: L_value = 15519.035731159329
# Success!  Iterations number: 13
# primal_func_value = 1206165.46445
# Duality_gap / Duality_gap_init = 0.0231044749273
# Phi big oracle elapsed time: 340 sec
# Elapsed time: 342 sec
# epsilon = 0.035938136638
# Oracles created...
# Universal similar triangles function...
# primal_init = 1264518.06716
# dual_init = -1170970.03287
# duality_gap_init = 93548.0342887
# Iterations number: 1
# Dual_gap_value = 93548.0342887
# primal_func_value = 1264518.06716
# Duality_gap / Duality_gap_init = 1.0
# Iterations number: 5
# Dual_gap_value = 68662.7943418
# primal_func_value = 1253316.63483
# Duality_gap / Duality_gap_init = 0.733984362834
# iteration_num = 9: L_value = 15519.035731159329
# iteration_num = 10: L_value = 15519.035731159329
# Iterations number: 10
# Dual_gap_value = 6733.996832
# primal_func_value = 1208594.66968
# Duality_gap / Duality_gap_init = 0.0719843755479
# iteration_num = 11: L_value = 15519.035731159329
# iteration_num = 12: L_value = 15519.035731159329
# Success!  Iterations number: 13
# primal_func_value = 1206165.46445
# Duality_gap / Duality_gap_init = 0.0231044749273
# Phi big oracle elapsed time: 340 sec
# Elapsed time: 341 sec
# epsilon = 0.0464158883361
# Oracles created...
# Universal similar triangles function...
# primal_init = 1264518.06716
# dual_init = -1170970.03287
# duality_gap_init = 93548.0342887
# Iterations number: 1
# Dual_gap_value = 93548.0342887
# primal_func_value = 1264518.06716
# Duality_gap / Duality_gap_init = 1.0
# Iterations number: 5
# Dual_gap_value = 68662.7943418
# primal_func_value = 1253316.63483
# Duality_gap / Duality_gap_init = 0.733984362834
# iteration_num = 9: L_value = 15519.035731159329
# iteration_num = 10: L_value = 15519.035731159329
# Iterations number: 10
# Dual_gap_value = 6733.996832
# primal_func_value = 1208594.66968
# Duality_gap / Duality_gap_init = 0.0719843755479
# iteration_num = 11: L_value = 15519.035731159329
# Success!  Iterations number: 12
# primal_func_value = 1207129.40257
# Duality_gap / Duality_gap_init = 0.0391735881838
# Phi big oracle elapsed time: 310 sec
# Elapsed time: 311 sec
# epsilon = 0.0599484250319
# Oracles created...
# Universal similar triangles function...
# primal_init = 1264518.06716
# dual_init = -1170970.03287
# duality_gap_init = 93548.0342887
# Iterations number: 1
# Dual_gap_value = 93548.0342887
# primal_func_value = 1264518.06716
# Duality_gap / Duality_gap_init = 1.0
# Iterations number: 5
# Dual_gap_value = 68662.7943418
# primal_func_value = 1253316.63483
# Duality_gap / Duality_gap_init = 0.733984362834
# iteration_num = 9: L_value = 15519.035731159329
# iteration_num = 10: L_value = 15519.035731159329
# Iterations number: 10
# Dual_gap_value = 6733.996832
# primal_func_value = 1208594.66968
# Duality_gap / Duality_gap_init = 0.0719843755479
# iteration_num = 11: L_value = 15519.035731159329
# Success!  Iterations number: 11
# primal_func_value = 1207615.84863
# Duality_gap / Duality_gap_init = 0.0516995542427
# Phi big oracle elapsed time: 307 sec
# Elapsed time: 309 sec
# epsilon = 0.0774263682681
# Oracles created...
# Universal similar triangles function...
# primal_init = 1264518.06716
# dual_init = -1170970.03287
# duality_gap_init = 93548.0342887
# Iterations number: 1
# Dual_gap_value = 93548.0342887
# primal_func_value = 1264518.06716
# Duality_gap / Duality_gap_init = 1.0
# Iterations number: 5
# Dual_gap_value = 68662.7943418
# primal_func_value = 1253316.63483
# Duality_gap / Duality_gap_init = 0.733984362834
# iteration_num = 10: L_value = 7759.517865579664
# Success!  Iterations number: 10
# primal_func_value = 1208290.35883
# Duality_gap / Duality_gap_init = 0.0598762880941
# Phi big oracle elapsed time: 271 sec
# Elapsed time: 272 sec
# epsilon = 0.1
# Oracles created...
# Universal similar triangles function...
# primal_init = 1264518.06716
# dual_init = -1170970.03287
# duality_gap_init = 93548.0342887
# Iterations number: 1
# Dual_gap_value = 93548.0342887
# primal_func_value = 1264518.06716
# Duality_gap / Duality_gap_init = 1.0
# Iterations number: 5
# Dual_gap_value = 68662.7943418
# primal_func_value = 1253316.63483
# Duality_gap / Duality_gap_init = 0.733984362834
# Success!  Iterations number: 9
# primal_func_value = 1209471.99596
# Duality_gap / Duality_gap_init = 0.0909737167155
# Phi big oracle elapsed time: 217 sec
# Elapsed time: 217 sec

# %%
result = {}
result['epsilons'] = epsilons
result['iter_nums'] = iter_nums_for_epsilons
result['exec_times'] = exec_times_for_epsilons
#flows vectorS
result['flows'] = flows

# %%
with open('anaheim_result_ustf_correct_epsilons_iter_nums_exec_times.pickle', 'wb') as f:
    pickle.dump(result, f)

# %%
with open('anaheim_result_ugd_epsilons_iter_nums_exec_times.pickle', 'rb') as f:
    result_ugd = pickle.load(f)

# %%
epsilons_ugd = result_ugd['epsilons']
assert(np.all(epsilons == epsilons_ugd))
iter_nums_for_epsilons_ugd = result_ugd['iter_nums']
exec_times_for_epsilons_ugd = result_ugd['exec_times']
flows_ugd = result_ugd['flows']

# %%
delta = []
for flow in flows:
    delta.append(np.linalg.norm(flow - flow_star, ord = 1) / np.linalg.norm(flow_star, ord = 1))

# %%
delta_ugd = []
for flow in flows_ugd:
    delta_ugd.append(np.linalg.norm(flow - flow_star, ord = 1) / np.linalg.norm(flow_star, ord = 1))

# %%
epsilons
# Out:
# array([ 0.01      ,  0.0129155 ,  0.01668101,  0.02154435,  0.02782559,
#         0.03593814,  0.04641589,  0.05994843,  0.07742637,  0.1       ])

# %%
duality_gap_histories[0]

# %%
plt.rc('text', usetex = True)

plt.plot(1.0 / epsilons, exec_times_for_epsilons, 'black', label = 'USTF', linewidth=2, marker='^')
plt.plot(1.0 / epsilons, exec_times_for_epsilons_ugd, 'blue', label = 'UGD', linewidth=2, marker='o')
#plt.title(r'$USTF vs UGD$')

plt.xlabel(r'$1 / \epsilon$')
plt.ylabel(r'times')
plt.legend()
legend = plt.legend(loc=0,fontsize=20)
text = legend.get_texts()[1]
props = text.get_font_properties().copy()
text.set_fontproperties(props)
text.set_size(20)

#plt.savefig('anaheim_times_vs_eps_ustf_correct_ugd.png', dpi = 300)
plt.show()

# %%
rho = 0.15
mu = 0.25
def primal_func_value(flows):
        sigma_sum_function = np.sum(graph.freeflow_times * flows * (rho * mu / (1.0 + mu) * 
                                    np.power(flows / graph.capacities, 1.0 / mu) + 1.0))
        return sigma_sum_function

# %% [markdown]
# ## Experiment 3  comparing USTF and Frank-Wolfe

# %% [markdown]
# Берем абсолютные значения $\epsilon$ !

# %%
epsilons = 500.0 * np.array([1, 2, 3, 4, 5])[::-1]
epsilons = [100.0]
epsilons
# Out:
# [100.0]

# %%
iter_nums_for_epsilons = []
exec_times_for_epsilons = []
flows = []
primal_func_hist = []

for epsilon in epsilons:
    tic = time.time()
    print('epsilon = ' + str(epsilon))
    result = model.model_solve(graph, graph_correspondences, total_od_flow,
                               solver_name = 'ustf',
                               mu = 0.25, rho = 0.15, epsilon = epsilon,
                               max_iter = 5000, verbose = True)
    toc = time.time()
    print('Elapsed time: {:.0f} sec'.format(toc - tic))
    exec_times_for_epsilons.append(toc - tic)
    iter_nums_for_epsilons.append(result['iter_num'])
    flows.append(result['flows'])
    primal_func_hist.append(result['primal_func_history'])
# Out:
# epsilon = 100.0
# Oracles created...
# Universal similar triangles function...
# primal_init = 1264518.06716
# dual_init = -1170970.03287
# duality_gap_init = 93548.0342887
# Iterations number: 1
# Dual_gap_value = 93548.0342887
# primal_func_value = 1264518.06716
# Duality_gap / Duality_gap_init = 1.0
# Iterations number: 5
# Dual_gap_value = 68662.7943418
# primal_func_value = 1253316.63483
# Duality_gap / Duality_gap_init = 0.733984362834
# iteration_num = 8: L_value = 31038.071462318658
# iteration_num = 9: L_value = 31038.071462318658
# iteration_num = 9: L_value = 62076.142924637315
# iteration_num = 9: L_value = 124152.28584927463
# iteration_num = 9: L_value = 248304.57169854926
# iteration_num = 9: L_value = 496609.1433970985
# Iterations number: 10
# Dual_gap_value = 11893.7242241
# primal_func_value = 1210127.92151
# Duality_gap / Duality_gap_init = 0.127140290168
# iteration_num = 13: L_value = 62076.142924637315
# iteration_num = 13: L_value = 124152.28584927463
# iteration_num = 14: L_value = 124152.28584927463
# iteration_num = 15: L_value = 124152.28584927463
# Iterations number: 15
# Dual_gap_value = 6224.57049817
# primal_func_value = 1207790.43361
# Duality_gap / Duality_gap_init = 0.0665387631658
# iteration_num = 16: L_value = 124152.28584927463
# iteration_num = 16: L_value = 248304.57169854926
# iteration_num = 16: L_value = 496609.1433970985
# iteration_num = 16: L_value = 993218.286794197
# iteration_num = 18: L_value = 496609.1433970985
# iteration_num = 19: L_value = 496609.1433970985
# iteration_num = 19: L_value = 993218.286794197
# iteration_num = 20: L_value = 993218.286794197
# iteration_num = 20: L_value = 1986436.573588394
# Iterations number: 20
# Dual_gap_value = 5167.86136497
# primal_func_value = 1207422.32975
# Duality_gap / Duality_gap_init = 0.0552428643131
# iteration_num = 21: L_value = 1986436.573588394
# iteration_num = 21: L_value = 3972873.147176788
# iteration_num = 22: L_value = 3972873.147176788
# iteration_num = 23: L_value = 3972873.147176788
# iteration_num = 23: L_value = 7945746.294353576
# iteration_num = 24: L_value = 7945746.294353576
# Iterations number: 25
# Dual_gap_value = 4835.36254155
# primal_func_value = 1207323.95252
# Duality_gap / Duality_gap_init = 0.0516885531408
# iteration_num = 28: L_value = 993218.286794197
# iteration_num = 28: L_value = 1986436.573588394
# iteration_num = 28: L_value = 3972873.147176788
# iteration_num = 28: L_value = 7945746.294353576
# iteration_num = 28: L_value = 15891492.588707153
# iteration_num = 30: L_value = 7945746.294353576
# Iterations number: 30
# Dual_gap_value = 4450.95036873
# primal_func_value = 1207198.1356
# Duality_gap / Duality_gap_init = 0.0475793040716
# iteration_num = 31: L_value = 7945746.294353576
# iteration_num = 33: L_value = 3972873.147176788
# iteration_num = 34: L_value = 3972873.147176788
# iteration_num = 34: L_value = 7945746.294353576
# Iterations number: 35
# Dual_gap_value = 4190.53564733
# primal_func_value = 1207132.60435
# Duality_gap / Duality_gap_init = 0.0447955499994
# iteration_num = 37: L_value = 1986436.573588394
# iteration_num = 37: L_value = 3972873.147176788
# iteration_num = 38: L_value = 3972873.147176788
# iteration_num = 38: L_value = 7945746.294353576
# iteration_num = 39: L_value = 7945746.294353576
# Iterations number: 40
# Dual_gap_value = 3919.82639854
# primal_func_value = 1207062.51473
# Duality_gap / Duality_gap_init = 0.0419017505643
# iteration_num = 41: L_value = 3972873.147176788
# iteration_num = 41: L_value = 7945746.294353576
# iteration_num = 42: L_value = 7945746.294353576
# iteration_num = 44: L_value = 3972873.147176788
# iteration_num = 44: L_value = 7945746.294353576
# iteration_num = 45: L_value = 7945746.294353576
# Iterations number: 45
# Dual_gap_value = 3716.23973966
# primal_func_value = 1207006.19398
# Duality_gap / Duality_gap_init = 0.0397254711755
# iteration_num = 46: L_value = 7945746.294353576
# iteration_num = 48: L_value = 3972873.147176788
# iteration_num = 50: L_value = 1986436.573588394
# iteration_num = 50: L_value = 3972873.147176788
# Iterations number: 50
# Dual_gap_value = 3469.5038222
# primal_func_value = 1206943.86766
# Duality_gap / Duality_gap_init = 0.037087939352
# iteration_num = 51: L_value = 3972873.147176788
# iteration_num = 51: L_value = 7945746.294353576
# iteration_num = 53: L_value = 3972873.147176788
# iteration_num = 54: L_value = 3972873.147176788
# iteration_num = 54: L_value = 7945746.294353576
# iteration_num = 54: L_value = 15891492.588707153
# Iterations number: 55
# Dual_gap_value = 3286.52841605
# primal_func_value = 1206891.75607
# Duality_gap / Duality_gap_init = 0.0351319879786
# iteration_num = 57: L_value = 3972873.147176788
# iteration_num = 58: L_value = 3972873.147176788
# iteration_num = 58: L_value = 7945746.294353576
# iteration_num = 59: L_value = 7945746.294353576
# Iterations number: 60
# Dual_gap_value = 2925.62128551
# primal_func_value = 1206625.52935
# Duality_gap / Duality_gap_init = 0.0312740006538
# iteration_num = 61: L_value = 3972873.147176788
# iteration_num = 62: L_value = 3972873.147176788
# iteration_num = 62: L_value = 7945746.294353576
# iteration_num = 64: L_value = 3972873.147176788
# Iterations number: 65
# Dual_gap_value = 2584.31746983
# primal_func_value = 1206389.0984
# Duality_gap / Duality_gap_init = 0.0276255667955
# iteration_num = 66: L_value = 1986436.573588394
# iteration_num = 67: L_value = 1986436.573588394
# iteration_num = 68: L_value = 1986436.573588394
# iteration_num = 69: L_value = 1986436.573588394
# iteration_num = 69: L_value = 3972873.147176788
# Iterations number: 70
# Dual_gap_value = 2235.45172753
# primal_func_value = 1206176.66484
# Duality_gap / Duality_gap_init = 0.0238962982443
# iteration_num = 71: L_value = 1986436.573588394
# iteration_num = 72: L_value = 1986436.573588394
# iteration_num = 72: L_value = 3972873.147176788
# iteration_num = 74: L_value = 1986436.573588394
# iteration_num = 74: L_value = 3972873.147176788
# Iterations number: 75
# Dual_gap_value = 1977.24460808
# primal_func_value = 1206043.45163
# Duality_gap / Duality_gap_init = 0.0211361427647
# iteration_num = 76: L_value = 1986436.573588394
# iteration_num = 76: L_value = 3972873.147176788
# iteration_num = 76: L_value = 7945746.294353576
# iteration_num = 79: L_value = 1986436.573588394
# iteration_num = 79: L_value = 3972873.147176788
# Iterations number: 80
# Dual_gap_value = 1786.49162694
# primal_func_value = 1205958.96232
# Duality_gap / Duality_gap_init = 0.019097051483
# iteration_num = 81: L_value = 1986436.573588394
# iteration_num = 81: L_value = 3972873.147176788
# iteration_num = 81: L_value = 7945746.294353576
# iteration_num = 83: L_value = 3972873.147176788
# iteration_num = 84: L_value = 3972873.147176788
# Iterations number: 85
# Dual_gap_value = 1634.63258534
# primal_func_value = 1205902.36107
# Duality_gap / Duality_gap_init = 0.0174737245713
# iteration_num = 86: L_value = 1986436.573588394
# iteration_num = 87: L_value = 1986436.573588394
# iteration_num = 88: L_value = 1986436.573588394
# iteration_num = 89: L_value = 1986436.573588394
# iteration_num = 90: L_value = 1986436.573588394
# Iterations number: 90
# Dual_gap_value = 1460.59465894
# primal_func_value = 1205854.7595
# Duality_gap / Duality_gap_init = 0.0156133121347
# iteration_num = 91: L_value = 1986436.573588394
# iteration_num = 92: L_value = 1986436.573588394
# iteration_num = 93: L_value = 1986436.573588394
# iteration_num = 93: L_value = 3972873.147176788
# iteration_num = 94: L_value = 3972873.147176788
# iteration_num = 94: L_value = 7945746.294353576
# Iterations number: 95
# Dual_gap_value = 1341.60818751
# primal_func_value = 1205829.62842
# Duality_gap / Duality_gap_init = 0.0143413829881
# iteration_num = 97: L_value = 1986436.573588394
# iteration_num = 97: L_value = 3972873.147176788
# iteration_num = 100: L_value = 993218.286794197
# iteration_num = 100: L_value = 1986436.573588394
# Iterations number: 100
# Dual_gap_value = 1239.96602434
# primal_func_value = 1205819.68186
# Duality_gap / Duality_gap_init = 0.0132548592151
# iteration_num = 102: L_value = 993218.286794197
# iteration_num = 102: L_value = 1986436.573588394
# iteration_num = 102: L_value = 3972873.147176788
# iteration_num = 103: L_value = 3972873.147176788
# iteration_num = 103: L_value = 7945746.294353576
# iteration_num = 104: L_value = 7945746.294353576
# Iterations number: 105
# Dual_gap_value = 1176.29116095
# primal_func_value = 1205810.47329
# Duality_gap / Duality_gap_init = 0.0125741943151
# iteration_num = 106: L_value = 3972873.147176788
# iteration_num = 106: L_value = 7945746.294353576
# iteration_num = 107: L_value = 7945746.294353576
# iteration_num = 107: L_value = 15891492.588707153
# iteration_num = 110: L_value = 3972873.147176788
# iteration_num = 110: L_value = 7945746.294353576
# Iterations number: 110
# Dual_gap_value = 1139.99883553
# primal_func_value = 1205809.47378
# Duality_gap / Duality_gap_init = 0.0121862404079
# iteration_num = 111: L_value = 7945746.294353576
# iteration_num = 113: L_value = 3972873.147176788
# iteration_num = 113: L_value = 7945746.294353576
# Iterations number: 115
# Dual_gap_value = 1095.35583771
# primal_func_value = 1205810.6077
# Duality_gap / Duality_gap_init = 0.0117090203556
# iteration_num = 116: L_value = 1986436.573588394
# iteration_num = 117: L_value = 1986436.573588394
# iteration_num = 117: L_value = 3972873.147176788
# iteration_num = 117: L_value = 7945746.294353576
# iteration_num = 117: L_value = 15891492.588707153
# iteration_num = 120: L_value = 3972873.147176788
# Iterations number: 120
# Dual_gap_value = 1047.08986905
# primal_func_value = 1205803.87595
# Duality_gap / Duality_gap_init = 0.0111930718482
# iteration_num = 121: L_value = 3972873.147176788
# iteration_num = 121: L_value = 7945746.294353576
# iteration_num = 123: L_value = 3972873.147176788
# iteration_num = 123: L_value = 7945746.294353576
# iteration_num = 125: L_value = 3972873.147176788
# iteration_num = 125: L_value = 7945746.294353576
# Iterations number: 125
# Dual_gap_value = 1007.96644115
# primal_func_value = 1205800.58444
# Duality_gap / Duality_gap_init = 0.0107748543175
# iteration_num = 127: L_value = 3972873.147176788
# iteration_num = 128: L_value = 3972873.147176788
# iteration_num = 130: L_value = 1986436.573588394
# Iterations number: 130
# Dual_gap_value = 955.215370282
# primal_func_value = 1205797.21487
# Duality_gap / Duality_gap_init = 0.0102109614333
# iteration_num = 131: L_value = 1986436.573588394
# iteration_num = 131: L_value = 3972873.147176788
# iteration_num = 132: L_value = 3972873.147176788
# iteration_num = 133: L_value = 3972873.147176788
# iteration_num = 133: L_value = 7945746.294353576
# iteration_num = 134: L_value = 7945746.294353576
# iteration_num = 134: L_value = 15891492.588707153
# Iterations number: 135
# Dual_gap_value = 925.062739332
# primal_func_value = 1205799.7892
# Duality_gap / Duality_gap_init = 0.00988863899029
# iteration_num = 137: L_value = 3972873.147176788
# iteration_num = 138: L_value = 3972873.147176788
# iteration_num = 138: L_value = 7945746.294353576
# iteration_num = 140: L_value = 3972873.147176788
# Iterations number: 140
# Dual_gap_value = 890.023002423
# primal_func_value = 1205802.59986
# Duality_gap / Duality_gap_init = 0.00951407487277
# iteration_num = 142: L_value = 1986436.573588394
# iteration_num = 143: L_value = 1986436.573588394
# iteration_num = 143: L_value = 3972873.147176788
# iteration_num = 145: L_value = 1986436.573588394
# iteration_num = 145: L_value = 3972873.147176788
# Iterations number: 145
# Dual_gap_value = 846.989965811
# primal_func_value = 1205808.08175
# Duality_gap / Duality_gap_init = 0.00905406481548
# iteration_num = 146: L_value = 3972873.147176788
# iteration_num = 147: L_value = 3972873.147176788
# iteration_num = 147: L_value = 7945746.294353576
# iteration_num = 148: L_value = 7945746.294353576
# iteration_num = 150: L_value = 3972873.147176788
# Iterations number: 150
# Dual_gap_value = 818.092278201
# primal_func_value = 1205812.16965
# Duality_gap / Duality_gap_init = 0.00874515733464
# iteration_num = 151: L_value = 3972873.147176788
# iteration_num = 154: L_value = 993218.286794197
# iteration_num = 154: L_value = 1986436.573588394
# iteration_num = 154: L_value = 3972873.147176788
# iteration_num = 155: L_value = 3972873.147176788
# Iterations number: 155
# Dual_gap_value = 756.973261754
# primal_func_value = 1205789.26284
# Duality_gap / Duality_gap_init = 0.00809181366033
# iteration_num = 156: L_value = 3972873.147176788
# iteration_num = 158: L_value = 1986436.573588394
# iteration_num = 160: L_value = 993218.286794197
# Iterations number: 160
# Dual_gap_value = 676.852311951
# primal_func_value = 1205744.73951
# Duality_gap / Duality_gap_init = 0.00723534510477
# iteration_num = 162: L_value = 496609.1433970985
# iteration_num = 162: L_value = 993218.286794197
# iteration_num = 164: L_value = 496609.1433970985
# iteration_num = 165: L_value = 496609.1433970985
# Iterations number: 165
# Dual_gap_value = 569.006013195
# primal_func_value = 1205703.14598
# Duality_gap / Duality_gap_init = 0.00608250101161
# iteration_num = 166: L_value = 496609.1433970985
# iteration_num = 167: L_value = 496609.1433970985
# iteration_num = 167: L_value = 993218.286794197
# iteration_num = 168: L_value = 993218.286794197
# iteration_num = 169: L_value = 993218.286794197
# iteration_num = 169: L_value = 1986436.573588394
# iteration_num = 169: L_value = 3972873.147176788
# Iterations number: 170
# Dual_gap_value = 516.658087411
# primal_func_value = 1205691.78721
# Duality_gap / Duality_gap_init = 0.00552291762558
# iteration_num = 171: L_value = 1986436.573588394
# iteration_num = 171: L_value = 3972873.147176788
# iteration_num = 171: L_value = 7945746.294353576
# iteration_num = 174: L_value = 1986436.573588394
# Iterations number: 175
# Dual_gap_value = 494.546896583
# primal_func_value = 1205691.36933
# Duality_gap / Duality_gap_init = 0.00528655572876
# iteration_num = 176: L_value = 993218.286794197
# iteration_num = 176: L_value = 1986436.573588394
# iteration_num = 177: L_value = 1986436.573588394
# iteration_num = 177: L_value = 3972873.147176788
# iteration_num = 179: L_value = 1986436.573588394
# iteration_num = 180: L_value = 1986436.573588394
# Iterations number: 180
# Dual_gap_value = 473.707591786
# primal_func_value = 1205692.99217
# Duality_gap / Duality_gap_init = 0.00506378990631
# iteration_num = 181: L_value = 1986436.573588394
# iteration_num = 181: L_value = 3972873.147176788
# iteration_num = 182: L_value = 3972873.147176788
# iteration_num = 184: L_value = 1986436.573588394
# iteration_num = 185: L_value = 1986436.573588394
# iteration_num = 185: L_value = 3972873.147176788
# Iterations number: 185
# Dual_gap_value = 455.369167779
# primal_func_value = 1205694.14198
# Duality_gap / Duality_gap_init = 0.00486775773795
# iteration_num = 187: L_value = 1986436.573588394
# iteration_num = 187: L_value = 3972873.147176788
# iteration_num = 188: L_value = 3972873.147176788
# iteration_num = 188: L_value = 7945746.294353576
# iteration_num = 190: L_value = 3972873.147176788
# Iterations number: 190
# Dual_gap_value = 440.074110785
# primal_func_value = 1205696.04483
# Duality_gap / Duality_gap_init = 0.00470425823623
# iteration_num = 191: L_value = 3972873.147176788
# iteration_num = 192: L_value = 3972873.147176788
# iteration_num = 192: L_value = 7945746.294353576
# Iterations number: 195
# Dual_gap_value = 417.375219462
# primal_func_value = 1205692.88844
# Duality_gap / Duality_gap_init = 0.00446161400007
# iteration_num = 196: L_value = 993218.286794197
# iteration_num = 197: L_value = 993218.286794197
# iteration_num = 198: L_value = 993218.286794197
# iteration_num = 198: L_value = 1986436.573588394
# iteration_num = 198: L_value = 3972873.147176788
# Iterations number: 200
# Dual_gap_value = 379.244384425
# primal_func_value = 1205674.77644
# Duality_gap / Duality_gap_init = 0.00405400698485
# iteration_num = 201: L_value = 993218.286794197
# iteration_num = 201: L_value = 1986436.573588394
# iteration_num = 203: L_value = 993218.286794197
# iteration_num = 204: L_value = 993218.286794197
# iteration_num = 205: L_value = 993218.286794197
# Iterations number: 205
# Dual_gap_value = 346.796146529
# primal_func_value = 1205666.47007
# Duality_gap / Duality_gap_init = 0.00370714520263
# iteration_num = 206: L_value = 993218.286794197
# iteration_num = 206: L_value = 1986436.573588394
# iteration_num = 207: L_value = 1986436.573588394
# iteration_num = 207: L_value = 3972873.147176788
# iteration_num = 209: L_value = 1986436.573588394
# iteration_num = 210: L_value = 1986436.573588394
# Iterations number: 210
# Dual_gap_value = 334.016339534
# primal_func_value = 1205668.3167
# Duality_gap / Duality_gap_init = 0.00357053295747
# iteration_num = 212: L_value = 993218.286794197
# iteration_num = 213: L_value = 993218.286794197
# iteration_num = 214: L_value = 993218.286794197
# iteration_num = 215: L_value = 993218.286794197
# Iterations number: 215
# Dual_gap_value = 305.815072796
# primal_func_value = 1205660.0307
# Duality_gap / Duality_gap_init = 0.00326907000367
# iteration_num = 216: L_value = 993218.286794197
# iteration_num = 216: L_value = 1986436.573588394
# iteration_num = 217: L_value = 1986436.573588394
# iteration_num = 218: L_value = 1986436.573588394
# iteration_num = 218: L_value = 3972873.147176788
# iteration_num = 220: L_value = 1986436.573588394
# iteration_num = 220: L_value = 3972873.147176788
# Iterations number: 220
# Dual_gap_value = 292.821283368
# primal_func_value = 1205658.67028
# Duality_gap / Duality_gap_init = 0.00313017035147
# iteration_num = 222: L_value = 1986436.573588394
# iteration_num = 223: L_value = 1986436.573588394
# iteration_num = 223: L_value = 3972873.147176788
# iteration_num = 223: L_value = 7945746.294353576
# iteration_num = 224: L_value = 7945746.294353576
# Iterations number: 225
# Dual_gap_value = 282.212810557
# primal_func_value = 1205657.22057
# Duality_gap / Duality_gap_init = 0.00301676900752
# iteration_num = 227: L_value = 1986436.573588394
# iteration_num = 227: L_value = 3972873.147176788
# iteration_num = 229: L_value = 1986436.573588394
# Iterations number: 230
# Dual_gap_value = 267.723711358
# primal_func_value = 1205654.29234
# Duality_gap / Duality_gap_init = 0.0028618849492
# iteration_num = 231: L_value = 993218.286794197
# iteration_num = 232: L_value = 993218.286794197
# iteration_num = 232: L_value = 1986436.573588394
# iteration_num = 233: L_value = 1986436.573588394
# iteration_num = 235: L_value = 993218.286794197
# iteration_num = 235: L_value = 1986436.573588394
# iteration_num = 235: L_value = 3972873.147176788
# Iterations number: 235
# Dual_gap_value = 251.406766334
# primal_func_value = 1205650.01182
# Duality_gap / Duality_gap_init = 0.00268746177561
# iteration_num = 236: L_value = 3972873.147176788
# iteration_num = 236: L_value = 7945746.294353576
# iteration_num = 237: L_value = 7945746.294353576
# iteration_num = 240: L_value = 1986436.573588394
# Iterations number: 240
# Dual_gap_value = 242.160814244
# primal_func_value = 1205648.23306
# Duality_gap / Duality_gap_init = 0.00258862536327
# iteration_num = 241: L_value = 1986436.573588394
# iteration_num = 242: L_value = 1986436.573588394
# iteration_num = 242: L_value = 3972873.147176788
# iteration_num = 242: L_value = 7945746.294353576
# iteration_num = 244: L_value = 3972873.147176788
# iteration_num = 244: L_value = 7945746.294353576
# Iterations number: 245
# Dual_gap_value = 233.881054067
# primal_func_value = 1205646.56788
# Duality_gap / Duality_gap_init = 0.00250011724827
# iteration_num = 247: L_value = 1986436.573588394
# iteration_num = 247: L_value = 3972873.147176788
# iteration_num = 249: L_value = 1986436.573588394
# iteration_num = 249: L_value = 3972873.147176788
# iteration_num = 250: L_value = 3972873.147176788
# Iterations number: 250
# Dual_gap_value = 224.768877133
# primal_func_value = 1205644.97284
# Duality_gap / Duality_gap_init = 0.00240271085162
# iteration_num = 251: L_value = 3972873.147176788
# iteration_num = 252: L_value = 3972873.147176788
# iteration_num = 254: L_value = 1986436.573588394
# iteration_num = 254: L_value = 3972873.147176788
# Iterations number: 255
# Dual_gap_value = 216.879079572
# primal_func_value = 1205644.11409
# Duality_gap / Duality_gap_init = 0.00231837131824
# iteration_num = 256: L_value = 1986436.573588394
# iteration_num = 257: L_value = 1986436.573588394
# iteration_num = 259: L_value = 993218.286794197
# iteration_num = 259: L_value = 1986436.573588394
# Iterations number: 260
# Dual_gap_value = 204.37500543
# primal_func_value = 1205641.04013
# Duality_gap / Duality_gap_init = 0.00218470657331
# iteration_num = 261: L_value = 993218.286794197
# iteration_num = 261: L_value = 1986436.573588394
# iteration_num = 261: L_value = 3972873.147176788
# iteration_num = 264: L_value = 993218.286794197
# iteration_num = 264: L_value = 1986436.573588394
# iteration_num = 264: L_value = 3972873.147176788
# Iterations number: 265
# Dual_gap_value = 195.777029272
# primal_func_value = 1205639.68127
# Duality_gap / Duality_gap_init = 0.00209279682636
# iteration_num = 267: L_value = 993218.286794197
# iteration_num = 267: L_value = 1986436.573588394
# iteration_num = 269: L_value = 993218.286794197
# iteration_num = 269: L_value = 1986436.573588394
# Iterations number: 270
# Dual_gap_value = 184.703475948
# primal_func_value = 1205637.43508
# Duality_gap / Duality_gap_init = 0.00197442391337
# iteration_num = 272: L_value = 496609.1433970985
# iteration_num = 273: L_value = 496609.1433970985
# iteration_num = 273: L_value = 993218.286794197
# iteration_num = 273: L_value = 1986436.573588394
# iteration_num = 274: L_value = 1986436.573588394
# iteration_num = 275: L_value = 1986436.573588394
# iteration_num = 275: L_value = 3972873.147176788
# Iterations number: 275
# Dual_gap_value = 174.859156835
# primal_func_value = 1205636.47271
# Duality_gap / Duality_gap_init = 0.00186919113976
# iteration_num = 277: L_value = 1986436.573588394
# iteration_num = 278: L_value = 1986436.573588394
# iteration_num = 279: L_value = 1986436.573588394
# iteration_num = 279: L_value = 3972873.147176788
# Iterations number: 280
# Dual_gap_value = 166.303785942
# primal_func_value = 1205633.72729
# Duality_gap / Duality_gap_init = 0.00177773683014
# iteration_num = 282: L_value = 993218.286794197
# iteration_num = 282: L_value = 1986436.573588394
# iteration_num = 283: L_value = 1986436.573588394
# iteration_num = 285: L_value = 993218.286794197
# iteration_num = 285: L_value = 1986436.573588394
# Iterations number: 285
# Dual_gap_value = 155.943476668
# primal_func_value = 1205628.76278
# Duality_gap / Duality_gap_init = 0.00166698827885
# iteration_num = 287: L_value = 993218.286794197
# iteration_num = 287: L_value = 1986436.573588394
# iteration_num = 287: L_value = 3972873.147176788
# iteration_num = 290: L_value = 993218.286794197
# iteration_num = 290: L_value = 1986436.573588394
# Iterations number: 290
# Dual_gap_value = 147.389047917
# primal_func_value = 1205625.6307
# Duality_gap / Duality_gap_init = 0.00157554404043
# iteration_num = 291: L_value = 1986436.573588394
# iteration_num = 292: L_value = 1986436.573588394
# iteration_num = 294: L_value = 993218.286794197
# iteration_num = 295: L_value = 993218.286794197
# Iterations number: 295
# Dual_gap_value = 139.330415499
# primal_func_value = 1205624.87944
# Duality_gap / Duality_gap_init = 0.00148939971383
# iteration_num = 297: L_value = 496609.1433970985
# iteration_num = 297: L_value = 993218.286794197
# iteration_num = 298: L_value = 993218.286794197
# iteration_num = 299: L_value = 993218.286794197
# iteration_num = 300: L_value = 993218.286794197
# Iterations number: 300
# Dual_gap_value = 130.60872248
# primal_func_value = 1205622.91178
# Duality_gap / Duality_gap_init = 0.00139616747133
# iteration_num = 301: L_value = 993218.286794197
# iteration_num = 301: L_value = 1986436.573588394
# iteration_num = 302: L_value = 1986436.573588394
# iteration_num = 305: L_value = 496609.1433970985
# iteration_num = 305: L_value = 993218.286794197
# Iterations number: 305
# Dual_gap_value = 124.311223187
# primal_func_value = 1205622.00602
# Duality_gap / Duality_gap_init = 0.00132884912154
# iteration_num = 307: L_value = 496609.1433970985
# iteration_num = 307: L_value = 993218.286794197
# iteration_num = 309: L_value = 496609.1433970985
# iteration_num = 309: L_value = 993218.286794197
# iteration_num = 310: L_value = 993218.286794197
# iteration_num = 310: L_value = 1986436.573588394
# Iterations number: 310
# Dual_gap_value = 116.113457941
# primal_func_value = 1205619.61916
# Duality_gap / Duality_gap_init = 0.00124121750739
# iteration_num = 312: L_value = 993218.286794197
# iteration_num = 312: L_value = 1986436.573588394
# iteration_num = 313: L_value = 1986436.573588394
# iteration_num = 313: L_value = 3972873.147176788
# Iterations number: 315
# Dual_gap_value = 111.045895754
# primal_func_value = 1205618.61402
# Duality_gap / Duality_gap_init = 0.00118704681075
# iteration_num = 316: L_value = 993218.286794197
# iteration_num = 316: L_value = 1986436.573588394
# iteration_num = 318: L_value = 993218.286794197
# iteration_num = 318: L_value = 1986436.573588394
# iteration_num = 318: L_value = 3972873.147176788
# Iterations number: 320
# Dual_gap_value = 106.276973075
# primal_func_value = 1205617.41674
# Duality_gap / Duality_gap_init = 0.0011360684795
# iteration_num = 321: L_value = 993218.286794197
# iteration_num = 321: L_value = 1986436.573588394
# iteration_num = 322: L_value = 1986436.573588394
# iteration_num = 324: L_value = 993218.286794197
# iteration_num = 324: L_value = 1986436.573588394
# iteration_num = 325: L_value = 1986436.573588394
# Iterations number: 325
# Dual_gap_value = 102.798271256
# primal_func_value = 1205617.36162
# Duality_gap / Duality_gap_init = 0.00109888221636
# iteration_num = 327: L_value = 993218.286794197
# iteration_num = 327: L_value = 1986436.573588394
# iteration_num = 328: L_value = 1986436.573588394
# Success!  Iterations number: 328
# primal_func_value = 1205616.14694
# Duality_gap / Duality_gap_init = 0.0010645990671
# Phi big oracle elapsed time: 12983 sec
# Elapsed time: 13034 sec

# %%
with open('anaheim_result_ustf_correct_epsilon_absolute_100.pickle', 'wb') as f:
    result['exec_time'] = exec_times_for_epsilons
    pickle.dump(result, f)

# %%
delta = []
for flow in flows:
    delta.append(np.linalg.norm(flow - flow_star, ord = 1) / np.linalg.norm(flow_star, ord = 1))
delta
# Out:
# [0.0023969949321912044]

# %%
with open('anaheim_result_ustf_correct_epsilon_absolute_100.pickle', 'rb') as f:
    result_ustf = pickle.load(f)
    primal_vals_ustf = result_ustf['primal_func_history']
    flows = [result_ustf['flows']]
len(primal_vals_ustf)
# Out:
# 328

# %%
with open('anaheim_result_fwa_epsilon_absolute_100.pickle', 'rb') as f:
    result_fwa = pickle.load(f)
    primal_vals_fwa = result_fwa['primal_func_history']
    flows = [result_fwa['flows']]
len(primal_vals_fwa)
# Out:
# 70

# %%
plt.rc('text', usetex = True)

plt.loglog(np.arange(1, len(primal_vals_ustf) + 1), primal_vals_ustf, 'black', label = 'USTF', linewidth=2, marker='^')
plt.loglog(np.arange(1, len(primal_vals_fwa) + 1), primal_vals_fwa, 'red', label = 'Frank-Wolfe', linewidth=2, marker='o')

plt.xlabel(r'$iteration$')
plt.ylabel(r'objective')
plt.legend()
legend = plt.legend(loc=0,fontsize=20)
text = legend.get_texts()[1]
props = text.get_font_properties().copy()
text.set_fontproperties(props)
text.set_size(20)

#plt.savefig('anaheim_primal__vs_iters_fwa_ustf_correct_eps_absolute_100_loglog.png', dpi = 300)
plt.show()

# %%
eps_abs = 200.0
relative_error_fwa = 0.0046729734770496511
iters_fwa = 41

# %%
eps_abs = 100.0
relative_error_fwa = 0.0023969949321912044
iters_fwa = 70
relative_error_ustf = 0.0021953059174468401
times_ustf = 328
